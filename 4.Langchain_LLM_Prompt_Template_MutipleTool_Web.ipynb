# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate
from langchain_core.tools import Tool
from langchain_community.tools.tavily_search import TavilySearchResults

# 🔑 API Keys
groq_api_key = "Your API KEY"
tavily_api_key = "Your API KEY"

# 🔸 Initialize Groq LLM
llm = ChatGroq(
    groq_api_key=groq_api_key,
    model_name="llama-3.1-8b-instant",
    temperature=0
)

# ✅ Tool 1: Simple QA

qa_prompt = PromptTemplate.from_template(
    "Answer clearly: {question}"
)

qa_chain = qa_prompt | llm

def qa_function(question):
    response = qa_chain.invoke({
        "question": question
    })
    return response.content

qa_tool = Tool(
    name="Simple QA",
    func=qa_function,
    description="Answer factual questions clearly"
)

# ✅ Tool 2: Summarizer

summary_prompt = PromptTemplate.from_template(
    "Summarize the following text:\n\n{text}"
)

summary_chain = summary_prompt | llm

def summary_function(text):
    response = summary_chain.invoke({
        "text": text
    })
    return response.content

summary_tool = Tool(
    name="Summarizer",
    func=summary_function,
    description="Summarizes input text"
)

# ✅ Tool 3: Web Search (Tavily)

search = TavilySearchResults(
    max_results=3,
    tavily_api_key=tavily_api_key
)

search_tool = Tool(
    name="Web Search",
    func=search.run,
    description="Search the internet for current information"
)

# 🧪 Inputs

qa_query = "What is LangGraph in LangChain?"

summary_text = """
LangGraph is a framework for building stateful multi-step agents using LangChain.
It uses graph-based design to model agent workflows and memory.
"""

search_query = "Latest updates on GPT-4o by OpenAI"

# 🚀 Run Tools

qa_answer = qa_tool.invoke(qa_query)

summary_answer = summary_tool.invoke(summary_text)

search_answer = search_tool.invoke(search_query)

# 🖨️ Output

print("\n🧠 Simple QA Tool Output:\n")
print(qa_answer)

print("\n📝 Summarizer Tool Output:\n")
print(summary_answer)

print("\n🌐 Web Search Tool Output:\n")
print(search_answer)
# Out:
# C:\Users\Vino Nandu\AppData\Local\Temp\ipykernel_11904\250624584.py:59: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   search = TavilySearchResults(
# 🧠 Simple QA Tool Output:
#
# LangChain is an open-source library for building conversational AI applications. LangGraph is a component within LangChain that enables the creation of graph-based data structures for storing and manipulating knowledge graphs.
#
# In LangChain, a graph is a data structure that consists of nodes and edges, where nodes represent entities or concepts, and edges represent relationships between them. LangGraph allows users to create, manipulate, and query these graphs in a flexible and efficient manner.
#
# Some key features of LangGraph include:
#
# 1. **Graph creation**: LangGraph provides a simple API for creating graphs from various data sources, such as text, databases, or other graph formats.
# 2. **Node and edge management**: Users can add, remove, and update nodes and edges in the graph, as well as query the graph to retrieve specific nodes or edges.
# 3. **Graph traversal**: LangGraph supports various graph traversal algorithms, such as breadth-first search (BFS) and depth-first search (DFS), to navigate the graph and retrieve relevant information.
# 4. **Querying**: Users can query the graph using natural language or SQL-like queries to retrieve specific information.
#
# LangGraph is designed to be highly flexible and customizable, allowing users to tailor the graph structure and behavior to their specific use case. This makes it an ideal component for building conversational AI applications that require complex knowledge graph management.
#
# In LangChain, LangGraph is often used in conjunction with other components, such as LangModel and LangDatabase, to build end-to-end conversational AI systems that can reason, answer questions, and perform tasks based on the knowledge graph.
#
# 📝 Summarizer Tool Output:
#
# LangGraph is a framework that allows developers to build stateful, multi-step agents using the LangChain library. It utilizes a graph-based design to model the workflows and memory of these agents.
#
# 🌐 Web Search Tool Output:
#
# [{'title': 'OpenAI will retire GPT-4 from ChatGPT on April 30, 2025 | Windows Central', 'url': 'https://www.windowscentral.com/software-apps/openai-discontinues-gpt-4-for-gpt-4o-in-chatgpt', 'content': 'As it turns out, OpenAI is getting ready to pull the plug on GPT-4. According to a changelog posted by the company late last week, GPT-4 will be effectively replaced by GPT-4o on April 30, 2025, as the default model in ChatGPT. However, GPT-4 will remain available via OpenAI\'s API.\n\nIn this photo illustration, the GitHub Copilot logo is seen displayed on a smartphone screen.\nOpenAI and Microsoft logos on a cracked screen\nThe ChatGPT app by OpenAI is shown on a cell phone\n\nAccording to OpenAI:\n\n“In head‑to‑head evaluations, [GPT-4o] consistently surpasses GPT‑4 in writing, coding, STEM, and more. Recent upgrades have further improved GPT‑4o’s instruction following, problem solving, and conversational flow, making it a natural successor to GPT‑4.” [...] Compared to GPT-4o, OpenAI CEO Sam Altman indicated that GPT-4 cost up to $100 million to train (via TechCrunch). Last year, the company unveiled GPT-4o with reasoning capabilities across text, audio, and voice, touting it as a faster iteration of its its predecessor, GPT-4.\n\nInterestingly, OpenAI\'s transition from GPT-4 to GPT-4o has seemingly drawn more traction to ChatGPT, adding one million new users in a little under an hour after launching its flashy image generator.\n\nAll the latest news, reviews, and guides for Windows and Xbox diehards.\n\nInterestingly, when GPT-4o launched in May 2024, ChatGPT experienced the biggest spike in revenue and downloads and mobile. [...] Over the past few years, generative AI has scaled great heights and become more advanced with incredible capabilities like OpenAI\'s new ChatGPT-4o image generator that went viral on social media with Studio Ghibli-inspired memes.\n\nOpenAI CEO Sam Altman has expressed his disappointment with the company\'s GPT-4, admitting that it "kind of sucks" and that it\'s mildly embarrassing at best. "GPT-4 is the dumbest model any of you will ever have to use again by a lot," added Altman. "It\'s important to ship early and often and we believe in iterative deployment."', 'score': 0.99923277}, {'title': 'GPT-4 contributions - OpenAI', 'url': 'https://openai.com/contributions/gpt-4/', 'content': 'Everyone at OpenAI has contributed to GPT-4. We thank Microsoft for their partnership, especially Microsoft Azure for supporting model training.', 'score': 0.9949397}, {'title': 'ChatGPT — Release Notes - OpenAI Help Center', 'url': 'https://help.openai.com/en/articles/6825453-chatgpt-release-notes', 'content': 'These updates add new app actions, including new write capabilities where supported, and bring the latest app experience into ChatGPT. If you already use these', 'score': 0.97719735}]
