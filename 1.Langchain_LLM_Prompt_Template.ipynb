# %%
#!pip install langchain-groq

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate

# API Key
groq_api_key = "Your Api Key"

# Latest Working Model
llm = ChatGroq(
    groq_api_key=groq_api_key,
    model_name="llama-3.1-8b-instant"
)

# Prompt
prompt = PromptTemplate.from_template(
    "Answer clearly: {question}"
)

# Chain
chain = prompt | llm

# Query
query = "What is LangGraph in LangChain?"

# Response
response = chain.invoke({
    "question": query
})

# Output
print("\nUser Question:", query)
print("\nLLM Answer:\n")
print(response.content)
# Out:
# User Question: What is LangGraph in LangChain?
#
# LLM Answer:
#
# In LangChain, LangGraph refers to a component that is used to represent and process complex knowledge graphs. It is designed to be a core component of the LangChain framework, which is a Python library for building conversational AI models.
#
# LangGraph is essentially a graph-based data structure that can be used to store and manipulate knowledge graphs, which are a type of graph that represents relationships between entities, concepts, and other nodes. These relationships can be based on various types of data, such as text, images, or other forms of media.
#
# The LangGraph component in LangChain is built on top of the PyTorch library and provides a number of features and tools for working with knowledge graphs, including:
#
# 1. **Graph construction**: LangGraph allows you to construct and manipulate knowledge graphs, including adding and removing nodes and edges, and querying the graph.
# 2. **Graph traversal**: LangGraph provides a number of algorithms for traversing the graph, including graph traversal algorithms like Breadth-First Search (BFS) and Depth-First Search (DFS).
# 3. **Graph querying**: LangGraph allows you to query the graph using a variety of query languages, including SPARQL and Cypher.
# 4. **Graph reasoning**: LangGraph provides a number of tools for reasoning about the graph, including inference and deduction.
#
# The LangGraph component in LangChain is designed to be highly flexible and customizable, allowing developers to easily integrate it with other components and tools in the LangChain framework.
#
# In summary, LangGraph is a key component of the LangChain framework that provides a powerful and flexible way to represent and process complex knowledge graphs.
